# %%
import pickle

# %%
sc=pickle.load(open("file_trail.sav","rb"))

# %%
in_put=sc.transform([[144372.41,118671.85,383199.62,0,1]])

# %%
model=pickle.load(open("file_md.sav","rb"))

# %%
model.predict(in_put)
# Out:
# array([7.78507963e+09])
